# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/mgilesj/Desktop/COMSC 230/Python Projects'

# %%
bankData = pd.read_csv('bank-data.csv')

# %%
bankData.columns = ['_id','age', 'sex', 'region', 'income', 'married', 'children', 'car', 'save_act', 'current_act', 'morgage', 'pep']

# %%
(bankData.pep).describe()
# Out:
# count     600
# unique      2
# top        NO
# freq      326
# Name: pep, dtype: object

# %%
(bankData.pep).describe()
# Out:
# count     600
# unique      2
# top        NO
# freq      326
# Name: pep, dtype: object

# %%
bankData["pep"].value_counts()
# Out:
# pep
# NO     326
# YES    274
# Name: count, dtype: int64

# %%
bankData.describe(include="all")
# Out:
#             _id         age     sex      region        income married  \
# count       600  485.000000     484         493    471.000000     473
# unique      600         NaN       2           4           NaN       2
# top     ID12101         NaN  FEMALE  INNER_CITY           NaN     YES
# freq          1         NaN     247         225           NaN     321
# mean        NaN   42.162887     NaN         NaN  27424.362059     NaN
# std         NaN   14.354293     NaN         NaN  12949.420946     NaN
# min         NaN   18.000000     NaN         NaN   5014.210000     NaN
# 25%         NaN   30.000000     NaN         NaN  17289.400000     NaN
# 50%         NaN   42.000000     NaN         NaN  24763.300000     NaN
# 75%         NaN   54.000000     NaN         NaN  36179.150000     NaN
# max         NaN   67.000000     NaN         NaN  63130.100000     NaN
#
#           children  car save_act current_act morgage  pep
# count   469.000000  491      476         474     480  600
# ...

# %%
bankData.income.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
bankData.boxplot(by='pep', column=['income'], grid = False)
# Out:
# <Axes: title={'center': 'income'}, xlabel='pep'>

# %%
bankData.boxplot(by='pep', column=['age'], grid = False)
# Out:
# <Axes: title={'center': 'age'}, xlabel='pep'>

# %%
bankData.boxplot(by='pep', column=['children'], grid = False)
# Out:
# <Axes: title={'center': 'children'}, xlabel='pep'>

# %%
# %matplotlib inline

# %%
histofram = bankData["pep"].hist()

# %%
bankData.plot(kind="barh", fontsize=3)
# Out:
# <Axes: >

# %%
bankData.plot(x="income", y="age", kind="scatter")
# Out:
# <Axes: xlabel='income', ylabel='age'>
